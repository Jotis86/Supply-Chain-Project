# %%
# Import librearies for data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import warnings 
warnings.filterwarnings('ignore')

# %%
# Load the data
data = pd.read_csv('cleaned_data.csv')

# %%
# Display the first 5 rows of the data
data.head()
# Out:
#     fecha_odc      nro_odc cod_prod cod_prov  cant_prod_odc  prec_unt  \
# 0  2018-01-08  ODC-1T-0001    P0001  PV00001             40       100
# 1  2018-01-08  ODC-1T-0001    P0002  PV00001             50       150
# 2  2018-01-08  ODC-1T-0001    P0003  PV00001             65       200
# 3  2018-01-12  ODC-1T-0002    P0004  PV00002             50       250
# 4  2018-01-12  ODC-1T-0002    P0005  PV00002             55       300
#
#    monto_odc fecha_entrega fecha_recibido  cant_recibida  ...  Subcategoria  \
# 0       4000    2018-03-09     2018-03-09             40  ...            TV
# 1       7500    2018-03-09     2018-03-09             50  ...            TV
# 2      13000    2018-03-09     2018-03-09             65  ...            TV
# 3      12500    2018-01-27     2018-01-27             50  ...            TV
# 4      16500    2018-01-27     2018-01-27             55  ...            TV
#
#   und_prod costo_prod  ontime  OTIF delivery_days reception_days  \
# 0     UND         100    True  True            60             60
# 1     UND         150    True  True            60             60
# 2     UND         200    True  True            60             60
# 3     UND         250    True  True            15             15
# 4     UND         300    True  True            15             15
#
#   percentage_received amount_difference  total_amount
# 0               100.0                 0          4000
# 1               100.0                 0          7500
# 2               100.0                 0         13000
# 3               100.0                 0         12500
# 4               100.0                 0         16500
#
# [5 rows x 27 columns]

# %%
# Convert date columns to datetime
data['fecha_odc'] = pd.to_datetime(data['fecha_odc'])
data['fecha_entrega'] = pd.to_datetime(data['fecha_entrega'])
data['fecha_recibido'] = pd.to_datetime(data['fecha_recibido'])


# Display the information of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272 entries, 0 to 271
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   fecha_odc            272 non-null    datetime64[ns]
#  1   nro_odc              272 non-null    object
#  2   cod_prod             272 non-null    object
#  3   cod_prov             272 non-null    object
#  4   cant_prod_odc        272 non-null    int64
#  5   prec_unt             272 non-null    int64
#  6   monto_odc            272 non-null    int64
#  7   fecha_entrega        272 non-null    datetime64[ns]
#  8   fecha_recibido       272 non-null    datetime64[ns]
#  9   cant_recibida        272 non-null    int64
#  10  monto_recibido       272 non-null    int64
#  11  estado_odc           272 non-null    object
#  12  nom_prov             272 non-null    object
#  13  tmp_entrega          272 non-null    int64
#  14  org_pais             272 non-null    object
#  15  descrip_prod         272 non-null    object
#  16  Categoria            272 non-null    object
#  17  Subcategoria         272 non-null    object
#  18  und_prod             272 non-null    object
#  19  costo_prod           272 non-null    int64
#  20  ontime               272 non-null    bool
#  21  OTIF                 272 non-null    bool
#  22  delivery_days        272 non-null    int64
#  23  reception_days       272 non-null    int64
#  24  percentage_received  272 non-null    float64
#  25  amount_difference    272 non-null    int64
#  26  total_amount         272 non-null    int64
# dtypes: bool(2), datetime64[ns](3), float64(1), int64(11), object(10)
# memory usage: 53.8+ KB

# %%
# 1. Histogram of ordered product quantity
plt.figure(figsize=(12, 8))
sns.set_style(style="whitegrid")

# Create the histogram
sns.histplot(data['cant_prod_odc'], bins=30, kde=True, color='skyblue')

# Add titles and labels
plt.title('Histogram of Ordered Product Quantity', fontsize=16)
plt.xlabel('Ordered Product Quantity', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Customize the ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Show the plot
plt.show()

# %%
# 2. Histogram of unit price
plt.figure(figsize=(12, 8))

# Create the histogram
sns.histplot(data['prec_unt'], bins=30, kde=True, color='salmon', edgecolor='black')

# Add titles and labels
plt.title('Histogram of Unit Price', fontsize=16, fontweight='bold')
plt.xlabel('Unit Price', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Customize the ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Add gridlines
plt.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
# 3. Histogram of order amount
plt.figure(figsize=(12, 8))

# Create the histogram
sns.histplot(data['monto_odc'], bins=30, kde=True, color='lightgreen', edgecolor='black')

# Add titles and labels
plt.title('Histogram of Order Amount', fontsize=16, fontweight='bold')
plt.xlabel('Order Amount', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Customize the ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Add gridlines
plt.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
# 4. Histogram of received quantity
plt.figure(figsize=(12, 8))

# Create the histogram
sns.histplot(data['cant_recibida'], bins=30, kde=True, color='lightblue', edgecolor='black')

# Add titles and labels
plt.title('Histogram of Received Quantity', fontsize=16, fontweight='bold')
plt.xlabel('Received Quantity', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Customize the ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Add gridlines
plt.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
# 5. Histogram of received amount
plt.figure(figsize=(12, 8))

# Create the histogram
sns.histplot(data['monto_recibido'], bins=30, kde=True, color='purple', edgecolor='black')

# Add titles and labels
plt.title('Histogram of Received Amount', fontsize=16, fontweight='bold')
plt.xlabel('Received Amount', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Customize the ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Add gridlines
plt.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
# 6. Bar plot of order status
plt.figure(figsize=(12, 8))


# Create the count plot
sns.countplot(data=data, x='estado_odc', palette='viridis', edgecolor='black')

# Add titles and labels
plt.title('Order Status Distribution', fontsize=18, fontweight='bold')
plt.xlabel('Order Status', fontsize=14)
plt.ylabel('Count', fontsize=14)

# Customize the ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Add gridlines
plt.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
# 7. Line plot of order amount over time
plt.figure(figsize=(12, 8))

# Create the line plot
sns.lineplot(data=data, x='fecha_odc', y='monto_odc', marker='o', color='b', linewidth=2.5)

# Add titles and labels
plt.title('Order Amount Over Time', fontsize=18, fontweight='bold')
plt.xlabel('Order Date', fontsize=14)
plt.ylabel('Order Amount', fontsize=14)

# Customize the ticks
plt.xticks(fontsize=12, rotation=45)
plt.yticks(fontsize=12)

# Add gridlines
plt.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
# 8. Line plot of received amount over time
plt.figure(figsize=(12, 8))

# Create the line plot with additional styling
sns.lineplot(data=data, x='fecha_odc', y='monto_recibido', marker='o', color='purple', linewidth=2.5)

# Add titles and labels with custom fonts and sizes
plt.title('Received Amount Over Time', fontsize=18, fontweight='bold')
plt.xlabel('Order Date', fontsize=14)
plt.ylabel('Received Amount', fontsize=14)

# Customize the ticks
plt.xticks(fontsize=12, rotation=45)
plt.yticks(fontsize=12)

# Add gridlines
plt.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
# 9. Box plot of unit price by order status
plt.figure(figsize=(12, 8))

# Create the box plot
sns.boxplot(data=data, x='estado_odc', y='prec_unt', palette='pastel', linewidth=2.5)

# Add titles and labels with custom fonts and sizes
plt.title('Unit Price by Order Status', fontsize=18, fontweight='bold')
plt.xlabel('Order Status', fontsize=14)
plt.ylabel('Unit Price', fontsize=14)

# Customize the ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Add gridlines
plt.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
# 10. Box plot of order amount by order status
plt.figure(figsize=(12, 8))

# Create the box plot with additional styling
sns.boxplot(data=data, x='estado_odc', y='monto_odc', palette='Set3', linewidth=2.5)

# Add titles and labels with custom fonts and sizes
plt.title('Order Amount by Order Status', fontsize=18, fontweight='bold')
plt.xlabel('Order Status', fontsize=14)
plt.ylabel('Order Amount', fontsize=14)

# Customize the ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Add gridlines
plt.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
# 11. Scatter plot of ordered quantity vs received quantity
plt.figure(figsize=(12, 8))

# Create the scatter plot with additional styling
sns.scatterplot(data=data, x='cant_prod_odc', y='cant_recibida', s=100, color='blue', edgecolor='black', alpha=0.7)

# Add titles and labels with custom fonts and sizes
plt.title('Ordered Quantity vs Received Quantity', fontsize=18, fontweight='bold')
plt.xlabel('Ordered Quantity', fontsize=14)
plt.ylabel('Received Quantity', fontsize=14)

# Customize the ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Add gridlines
plt.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
# 12. Scatter plot of order amount vs received amount
plt.figure(figsize=(12, 8))

# Create the scatter plot with additional styling
sns.scatterplot(data=data, x='monto_odc', y='monto_recibido', s=100, color='blue', edgecolor='black', alpha=0.7)

# Add titles and labels with custom fonts and sizes
plt.title('Order Amount vs Received Amount', fontsize=18, fontweight='bold')
plt.xlabel('Order Amount', fontsize=14)
plt.ylabel('Received Amount', fontsize=14)

# Customize the ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Add gridlines
plt.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
# 13. Bar plot of on-time deliveries
plt.figure(figsize=(12, 8))
sns.set_style("whitegrid")

# Create the count plot with additional styling
sns.countplot(data=data, x='ontime', palette='coolwarm', edgecolor='black')

# Add titles and labels with custom fonts and sizes
plt.title('On-time Deliveries', fontsize=18, fontweight='bold')
plt.xlabel('On-time', fontsize=14)
plt.ylabel('Count', fontsize=14)

# Customize the ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Add gridlines
plt.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
# 14. Bar plot of OTIF deliveries
plt.figure(figsize=(12, 8))
sns.set_style("whitegrid")

# Create the count plot with additional styling
sns.countplot(data=data, x='OTIF', palette='coolwarm', edgecolor='black')

# Add titles and labels with custom fonts and sizes
plt.title('OTIF Deliveries', fontsize=18, fontweight='bold')
plt.xlabel('OTIF', fontsize=14)
plt.ylabel('Count', fontsize=14)

# Customize the ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Add gridlines
plt.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
# 2. Bar plot of origin country
plt.figure(figsize=(12, 6))
sns.countplot(data=data, x='org_pais', palette='magma')
plt.title('Origin Country Distribution', fontsize=18)
plt.xlabel('Origin Country', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
# 3. Box plot of unit price by category
plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x='Categoria', y='prec_unt', palette='coolwarm')
plt.title('Unit Price by Category', fontsize=18)
plt.xlabel('Category', fontsize=14)
plt.ylabel('Unit Price', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
# 4. Box plot of unit price by subcategory
plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x='Subcategoria', y='prec_unt', palette='coolwarm')
plt.title('Unit Price by Subcategory', fontsize=18)
plt.xlabel('Subcategory', fontsize=14)
plt.ylabel('Unit Price', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
# 5. Scatter plot of cost vs unit price
plt.figure(figsize=(12, 6))
sns.scatterplot(data=data, x='costo_prod', y='prec_unt', color='darkblue', s=100, alpha=0.6)
plt.title('Cost vs Unit Price', fontsize=18)
plt.xlabel('Cost', fontsize=14)
plt.ylabel('Unit Price', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
# 6. Scatter plot of delivery days vs reception days
plt.figure(figsize=(12, 6))
sns.scatterplot(data=data, x='delivery_days', y='reception_days', color='darkgreen', s=100, alpha=0.6)
plt.title('Delivery Days vs Reception Days', fontsize=18)
plt.xlabel('Delivery Days', fontsize=14)
plt.ylabel('Reception Days', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
# 9. Bar plot of on-time deliveries by provider
plt.figure(figsize=(10, 6))

# Convert 'ontime' column to string type
data['ontime'] = data['ontime'].astype(str)

sns.countplot(data=data, x='nom_prov', hue='ontime', palette='Set2')
plt.title('On-time Deliveries by Provider', fontsize=15)
plt.xlabel('Provider', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %%
# 10. Bar plot of OTIF deliveries by provider
plt.figure(figsize=(10, 6))

# Convert 'OTIF' column to string type
data['OTIF'] = data['OTIF'].astype(str)

sns.countplot(data=data, x='nom_prov', hue='OTIF', palette='Set3')
plt.title('OTIF Deliveries by Provider', fontsize=15)
plt.xlabel('Provider', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %%
# Set up the matplotlib figure
fig, axes = plt.subplots(5, 2, figsize=(20, 25))
fig.suptitle('Dashboard Summary', fontsize=20)

# 1. Bar plot of order status
sns.countplot(data=data, x='estado_odc', ax=axes[0, 0], palette='viridis')
axes[0, 0].set_title('Order Status Distribution', fontsize=15)
axes[0, 0].set_xlabel('Order Status', fontsize=12)
axes[0, 0].set_ylabel('Count', fontsize=12)

# 2. Bar plot of origin country
sns.countplot(data=data, x='org_pais', ax=axes[0, 1], palette='magma')
axes[0, 1].set_title('Origin Country Distribution', fontsize=15)
axes[0, 1].set_xlabel('Origin Country', fontsize=12)
axes[0, 1].set_ylabel('Count', fontsize=12)

# 3. Box plot of unit price by category
sns.boxplot(data=data, x='Categoria', y='prec_unt', ax=axes[1, 0], palette='coolwarm')
axes[1, 0].set_title('Unit Price by Category', fontsize=15)
axes[1, 0].set_xlabel('Category', fontsize=12)
axes[1, 0].set_ylabel('Unit Price', fontsize=12)
axes[1, 0].tick_params(axis='x', rotation=45)

# 4. Box plot of unit price by subcategory
sns.boxplot(data=data, x='Subcategoria', y='prec_unt', ax=axes[1, 1], palette='coolwarm')
axes[1, 1].set_title('Unit Price by Subcategory', fontsize=15)
axes[1, 1].set_xlabel('Subcategory', fontsize=12)
axes[1, 1].set_ylabel('Unit Price', fontsize=12)
axes[1, 1].tick_params(axis='x', rotation=45)

# 5. Scatter plot of cost vs unit price
sns.scatterplot(data=data, x='costo_prod', y='prec_unt', ax=axes[2, 0], color='darkblue', s=100, alpha=0.6)
axes[2, 0].set_title('Cost vs Unit Price', fontsize=15)
axes[2, 0].set_xlabel('Cost', fontsize=12)
axes[2, 0].set_ylabel('Unit Price', fontsize=12)

# 6. Scatter plot of delivery days vs reception days
sns.scatterplot(data=data, x='delivery_days', y='reception_days', ax=axes[2, 1], color='darkgreen', s=100, alpha=0.6)
axes[2, 1].set_title('Delivery Days vs Reception Days', fontsize=15)
axes[2, 1].set_xlabel('Delivery Days', fontsize=12)
axes[2, 1].set_ylabel('Reception Days', fontsize=12)

# 7. Line plot of total amount over time
sns.lineplot(data=data, x='fecha_odc', y='total_amount', ax=axes[3, 0], color='coral', linewidth=2.5)
axes[3, 0].set_title('Total Amount Over Time', fontsize=15)
axes[3, 0].set_xlabel('Order Date', fontsize=12)
axes[3, 0].set_ylabel('Total Amount', fontsize=12)

# 8. Bar plot of total amount by category
category_sales = data.groupby('Categoria')['total_amount'].sum().reset_index()
sns.barplot(data=category_sales, x='Categoria', y='total_amount', ax=axes[3, 1], palette='Blues_d')
axes[3, 1].set_title('Total Amount by Category', fontsize=15)
axes[3, 1].set_xlabel('Category', fontsize=12)
axes[3, 1].set_ylabel('Total Amount', fontsize=12)
axes[3, 1].tick_params(axis='x', rotation=45)

# 9. Bar plot of on-time deliveries by provider
sns.countplot(data=data, x='nom_prov', hue='ontime', ax=axes[4, 0], palette='Set2')
axes[4, 0].set_title('On-time Deliveries by Provider', fontsize=15)
axes[4, 0].set_xlabel('Provider', fontsize=12)
axes[4, 0].set_ylabel('Count', fontsize=12)
axes[4, 0].tick_params(axis='x', rotation=90)
axes[4, 0].legend(title='On-time', fontsize=12)

# 10. Bar plot of OTIF deliveries by provider
sns.countplot(data=data, x='nom_prov', hue='OTIF', ax=axes[4, 1], palette='Set3')
axes[4, 1].set_title('OTIF Deliveries by Provider', fontsize=15)
axes[4, 1].set_xlabel('Provider', fontsize=12)
axes[4, 1].set_ylabel('Count', fontsize=12)
axes[4, 1].tick_params(axis='x', rotation=90)
axes[4, 1].legend(title='OTIF', fontsize=12)

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
